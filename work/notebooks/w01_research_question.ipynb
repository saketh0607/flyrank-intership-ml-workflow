# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saketh0607/flyrank-intership-ml-workflow/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
## My Lane
"""I choose the "Predict Pages That May Decline in Search Performance" lane.
I selected this lane because websites have many pages, and it is difficult to monitor every page manually. If we can predict which pages are likely to decline, the SEO team can review those pages first and improve them before they lose traffic.
I am interested in learning how machine learning can use historical search data to make useful predictions."""
# Out:
# 'I choose the "Predict Pages That May Decline in Search Performance" lane.\nI selected this lane because websites have many pages, and it is difficult to monitor every page manually. If we can predict which pages are likely to decline, the SEO team can review those pages first and improve them before they lose traffic.\nI am interested in learning how machine learning can use historical search data to make useful predictions.'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
## Decision
"""My project helps the SEO team decide which webpages should be reviewed first because they may lose search traffic."""
## Who takes the action?
"""The SEO team or content team will use the prediction to decide which pages need improvement."""
## Action
"""If a webpage is predicted to decline, the team can:
- Update the content
- Improve keywords
- Refresh outdated information
- Fix SEO issues"""
## Cost of a Wrong Recommendation
"""False Positive:
         The model predicts a decline when the page is actually performing well. This wastes time because the team works on a page that did not need changes.
False Negative:
        The model predicts a page is fine, but it actually declines. This may reduce website traffic because the page was not improved in time."""
# Out:
# 'False Positive:\n         The model predicts a decline when the page is actually performing well. This wastes time because the team works on a page that did not need changes.\nFalse Negative:\n        The model predicts a page is fine, but it actually declines. This may reduce website traffic because the page was not improved in time.'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
## Quick Look at the Dataset

print("""I explored the dataset to understand its size and the available information.
Some useful statistics are:
- Total records
- Total columns
- Average CTR
- Average search position
- Average content age
These numbers help me understand whether the dataset is suitable for solving my chosen problem.""")
# Out:
# I explored the dataset to understand its size and the available information.
# Some useful statistics are:
# - Total records
# - Total columns
# - Average CTR
# - Average search position
# - Average content age
# These numbers help me understand whether the dataset is suitable for solving my chosen problem.

# %%
import os
os.chdir("/content/flyrank-intership-ml-workflow")
print(os.getcwd())
# Out:
# /content/flyrank-intership-ml-workflow

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print("Total Rows:", len(df))
print("Total Columns:", len(df.columns))

print("\nTrend Distribution:")
print(df["trend_direction"].value_counts())

print("\nAverage CTR:", round(df["ctr"].mean(), 2))
print("Average Search Position:", round(df["avg_position"].mean(), 2))
print("Average Content Age:", round(df["content_age_days"].mean(), 2))
# Out:
# Total Rows: 30000
# Total Columns: 44
#
# Trend Distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average CTR: 0.51
# Average Search Position: 16.34
# Average Content Age: 256.17

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
### What my project can claim
"""
- My model can find patterns in historical search data.
- It can estimate whether a webpage is more or less likely to decline in search performance.
- The predictions can help the SEO team decide which pages to review first.
- This project is a decision-support tool, not a final decision-maker."""

### What my project cannot claim
"""
- My model cannot prove why a webpage's search performance changes.
- It cannot predict Google's ranking algorithm or future updates.
- It cannot guarantee that a page will definitely decline or improve.
- The predictions should be used together with human knowledge and SEO expertise."""
# Out:
# "\n- My model cannot prove why a webpage's search performance changes.\n- It cannot predict Google's ranking algorithm or future updates.\n- It cannot guarantee that a page will definitely decline or improve.\n- The predictions should be used together with human knowledge and SEO expertise."

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %%
#Self-Check
print("""✅ Every section above is filled - markdown thinking AND the code that backs it

✅ The notebook runs from top to bottom with no errors (Runtime → Run all)

✅ No client names, URLs, or private queries anywhere

✅ My claims use careful words: observed, measured, directional, decision support

✅ Committed to my repo under 'work/notebooks/' - then submit my repo URL on the card. Done.
""")
# Out:
# ✅ Every section above is filled - markdown thinking AND the code that backs it
#
# ✅ The notebook runs from top to bottom with no errors (Runtime → Run all)
#
# ✅ No client names, URLs, or private queries anywhere
#
# ✅ My claims use careful words: observed, measured, directional, decision support
#
# ✅ Committed to my repo under 'work/notebooks/' - then submit my repo URL on the card. Done.
